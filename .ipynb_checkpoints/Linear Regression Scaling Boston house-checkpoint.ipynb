# %% [markdown]
# ## Import Libraries

# %%
import pandas as pd
import numpy as np

from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression

from sklearn.metrics import r2_score, mean_absolute_error, mean_squared_error

from statsmodels.stats.outliers_influence import variance_inflation_factor

import matplotlib.pyplot as plt
import seaborn as sns

# %%
import warnings

# %%
warnings.filterwarnings("ignore")

# %% [markdown]
# ## Data Gathering

# %%
from sklearn.datasets import load_boston

# %%
data_dict = load_boston()

# %%
df = pd.DataFrame(data = data_dict.data, columns=data_dict.feature_names)

# %%
df
# Out:
#         CRIM    ZN  INDUS  CHAS    NOX     RM   AGE     DIS  RAD    TAX  PTRATIO       B  LSTAT
# 0    0.00632  18.0   2.31   0.0  0.538  6.575  65.2  4.0900  1.0  296.0     15.3  396.90   4.98
# 1    0.02731   0.0   7.07   0.0  0.469  6.421  78.9  4.9671  2.0  242.0     17.8  396.90   9.14
# 2    0.02729   0.0   7.07   0.0  0.469  7.185  61.1  4.9671  2.0  242.0     17.8  392.83   4.03
# 3    0.03237   0.0   2.18   0.0  0.458  6.998  45.8  6.0622  3.0  222.0     18.7  394.63   2.94
# 4    0.06905   0.0   2.18   0.0  0.458  7.147  54.2  6.0622  3.0  222.0     18.7  396.90   5.33
# ..       ...   ...    ...   ...    ...    ...   ...     ...  ...    ...      ...     ...    ...
# 501  0.06263   0.0  11.93   0.0  0.573  6.593  69.1  2.4786  1.0  273.0     21.0  391.99   9.67
# 502  0.04527   0.0  11.93   0.0  0.573  6.120  76.7  2.2875  1.0  273.0     21.0  396.90   9.08
# 503  0.06076   0.0  11.93   0.0  0.573  6.976  91.0  2.1675  1.0  273.0     21.0  396.90   5.64
# ...

# %%
df["House_Price"] = data_dict.target

# %%
df
# Out:
#         CRIM    ZN  INDUS  CHAS    NOX     RM   AGE     DIS  RAD    TAX  PTRATIO       B  LSTAT  House_Price
# 0    0.00632  18.0   2.31   0.0  0.538  6.575  65.2  4.0900  1.0  296.0     15.3  396.90   4.98         24.0
# 1    0.02731   0.0   7.07   0.0  0.469  6.421  78.9  4.9671  2.0  242.0     17.8  396.90   9.14         21.6
# 2    0.02729   0.0   7.07   0.0  0.469  7.185  61.1  4.9671  2.0  242.0     17.8  392.83   4.03         34.7
# 3    0.03237   0.0   2.18   0.0  0.458  6.998  45.8  6.0622  3.0  222.0     18.7  394.63   2.94         33.4
# 4    0.06905   0.0   2.18   0.0  0.458  7.147  54.2  6.0622  3.0  222.0     18.7  396.90   5.33         36.2
# ..       ...   ...    ...   ...    ...    ...   ...     ...  ...    ...      ...     ...    ...          ...
# 501  0.06263   0.0  11.93   0.0  0.573  6.593  69.1  2.4786  1.0  273.0     21.0  391.99   9.67         22.4
# 502  0.04527   0.0  11.93   0.0  0.573  6.120  76.7  2.2875  1.0  273.0     21.0  396.90   9.08         20.6
# ...

# %% [markdown]
# ## Exploratory Data Analysis (EDA)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 506 entries, 0 to 505
# Data columns (total 14 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   CRIM         506 non-null    float64
#  1   ZN           506 non-null    float64
#  2   INDUS        506 non-null    float64
#  3   CHAS         506 non-null    float64
#  4   NOX          506 non-null    float64
#  5   RM           506 non-null    float64
#  6   AGE          506 non-null    float64
#  7   DIS          506 non-null    float64
#  8   RAD          506 non-null    float64
#  9   TAX          506 non-null    float64
#  10  PTRATIO      506 non-null    float64
#  11  B            506 non-null    float64
#  12  LSTAT        506 non-null    float64
#  13  House_Price  506 non-null    float64
# dtypes: float64(14)
# memory usage: 55.5 KB

# %%
df.describe()
# Out:
#              CRIM          ZN       INDUS        CHAS  ...     PTRATIO           B       LSTAT  House_Price
# count  506.000000  506.000000  506.000000  506.000000  ...  506.000000  506.000000  506.000000   506.000000
# mean     3.613524   11.363636   11.136779    0.069170  ...   18.455534  356.674032   12.653063    22.532806
# std      8.601545   23.322453    6.860353    0.253994  ...    2.164946   91.294864    7.141062     9.197104
# min      0.006320    0.000000    0.460000    0.000000  ...   12.600000    0.320000    1.730000     5.000000
# 25%      0.082045    0.000000    5.190000    0.000000  ...   17.400000  375.377500    6.950000    17.025000
# 50%      0.256510    0.000000    9.690000    0.000000  ...   19.050000  391.440000   11.360000    21.200000
# 75%      3.677083   12.500000   18.100000    0.000000  ...   20.200000  396.225000   16.955000    25.000000
# max     88.976200  100.000000   27.740000    1.000000  ...   22.000000  396.900000   37.970000    50.000000
#
# ...

# %%
df.isna().sum()
# Out:
# CRIM           0
# ZN             0
# INDUS          0
# CHAS           0
# NOX            0
# RM             0
# AGE            0
# DIS            0
# RAD            0
# TAX            0
# PTRATIO        0
# B              0
# LSTAT          0
# House_Price    0
# dtype: int64

# %%
sns.distplot(df["CRIM"])
# Out:
# <AxesSubplot:xlabel='CRIM', ylabel='Density'>

# %%
sns.kdeplot(df["CRIM"])
# Out:
# <AxesSubplot:xlabel='CRIM', ylabel='Density'>

# %%
len(df.columns)
# Out:
# 14

# %%
i = 1
plt.figure(figsize=(24,30))
for col in df.columns:
    plt.subplot(5,3,i)
    sns.kdeplot(df[col])
    i += 1

# %%
plt.figure(figsize=(20,20))
sns.heatmap(df.corr(), annot = True)
# Out:
# <AxesSubplot:>

# %%
vif_list = []
for i in range(df.shape[1]):
    vif = variance_inflation_factor(df.to_numpy(),i)
    vif_list.append(vif)
    
vif_series = pd.Series(vif_list, index = df.columns)
vif_series.sort_values().plot(kind = "barh")
# Out:
# <AxesSubplot:>

# %% [markdown]
# ## Feature Engineering

# %% [markdown]
# ## Train The Model

# %%
x = df.drop("House_Price", axis = 1)
y = df["House_Price"]

# %%
x.head()
# Out:
#       CRIM    ZN  INDUS  CHAS    NOX     RM   AGE     DIS  RAD    TAX  PTRATIO       B  LSTAT
# 0  0.00632  18.0   2.31   0.0  0.538  6.575  65.2  4.0900  1.0  296.0     15.3  396.90   4.98
# 1  0.02731   0.0   7.07   0.0  0.469  6.421  78.9  4.9671  2.0  242.0     17.8  396.90   9.14
# 2  0.02729   0.0   7.07   0.0  0.469  7.185  61.1  4.9671  2.0  242.0     17.8  392.83   4.03
# 3  0.03237   0.0   2.18   0.0  0.458  6.998  45.8  6.0622  3.0  222.0     18.7  394.63   2.94
# 4  0.06905   0.0   2.18   0.0  0.458  7.147  54.2  6.0622  3.0  222.0     18.7  396.90   5.33

# %%
y
# Out:
# 0      24.0
# 1      21.6
# 2      34.7
# 3      33.4
# 4      36.2
#        ...
# 501    22.4
# 502    20.6
# 503    23.9
# 504    22.0
# 505    11.9
# Name: House_Price, Length: 506, dtype: float64

# %%
x_train, x_test, y_train, y_test = train_test_split(x,y)

# %%
lr_model = LinearRegression()

# %%
lr_model.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
y_pred = lr_model.predict(x_test)

# %% [markdown]
# ## Evaluation of model

# %%
mse = mean_squared_error(y_test,y_pred)
rmse = np.sqrt(mse)
mae = mean_absolute_error(y_test,y_pred)
r2score = r2_score(y_test,y_pred)

print(f"Mean Squared Error: {mse:0.4f}")
print(f"Root mean Squared Error: {rmse:0.4f}")
print(f"Mean Absolute Error: {mae:0.4f}")
print(f"R2 Score: {r2score:0.4f}")
# Out:
# Mean Squared Error: 27.8526
# Root mean Squared Error: 5.2776
# Mean Absolute Error: 3.4776
# R2 Score: 0.6376

# %% [markdown]
# ## Scaling the data

# %%
from sklearn.preprocessing import MinMaxScaler

# %%
scaler = MinMaxScaler()
scaler.fit(x)

x_scaled = scaler.transform(x)

x_scaled
# Out:
# array([[0.00000000e+00, 1.80000000e-01, 6.78152493e-02, ...,
#         2.87234043e-01, 1.00000000e+00, 8.96799117e-02],
#        [2.35922539e-04, 0.00000000e+00, 2.42302053e-01, ...,
#         5.53191489e-01, 1.00000000e+00, 2.04470199e-01],
#        [2.35697744e-04, 0.00000000e+00, 2.42302053e-01, ...,
#         5.53191489e-01, 9.89737254e-01, 6.34657837e-02],
#        ...,
#        [6.11892474e-04, 0.00000000e+00, 4.20454545e-01, ...,
#         8.93617021e-01, 1.00000000e+00, 1.07891832e-01],
#        [1.16072990e-03, 0.00000000e+00, 4.20454545e-01, ...,
#         8.93617021e-01, 9.91300620e-01, 1.31070640e-01],
#        [4.61841693e-04, 0.00000000e+00, 4.20454545e-01, ...,
#         8.93617021e-01, 1.00000000e+00, 1.69701987e-01]])

# %%
x_scaled = pd.DataFrame(x_scaled, columns = x.columns)

# %%
x_scaled.head()
# Out:
#        CRIM    ZN     INDUS  CHAS       NOX        RM  ...       DIS       RAD       TAX   PTRATIO         B     LSTAT
# 0  0.000000  0.18  0.067815   0.0  0.314815  0.577505  ...  0.269203  0.000000  0.208015  0.287234  1.000000  0.089680
# 1  0.000236  0.00  0.242302   0.0  0.172840  0.547998  ...  0.348962  0.043478  0.104962  0.553191  1.000000  0.204470
# 2  0.000236  0.00  0.242302   0.0  0.172840  0.694386  ...  0.348962  0.043478  0.104962  0.553191  0.989737  0.063466
# 3  0.000293  0.00  0.063050   0.0  0.150206  0.658555  ...  0.448545  0.086957  0.066794  0.648936  0.994276  0.033389
# 4  0.000705  0.00  0.063050   0.0  0.150206  0.687105  ...  0.448545  0.086957  0.066794  0.648936  1.000000  0.099338
#
# [5 rows x 13 columns]

# %%
x.head()
# Out:
#       CRIM    ZN  INDUS  CHAS    NOX     RM   AGE     DIS  RAD    TAX  PTRATIO       B  LSTAT
# 0  0.00632  18.0   2.31   0.0  0.538  6.575  65.2  4.0900  1.0  296.0     15.3  396.90   4.98
# 1  0.02731   0.0   7.07   0.0  0.469  6.421  78.9  4.9671  2.0  242.0     17.8  396.90   9.14
# 2  0.02729   0.0   7.07   0.0  0.469  7.185  61.1  4.9671  2.0  242.0     17.8  392.83   4.03
# 3  0.03237   0.0   2.18   0.0  0.458  6.998  45.8  6.0622  3.0  222.0     18.7  394.63   2.94
# 4  0.06905   0.0   2.18   0.0  0.458  7.147  54.2  6.0622  3.0  222.0     18.7  396.90   5.33

# %%
plt.figure(figsize=(16,6))
plt.subplot(1,2,1)
plt.scatter(x.index,x["AGE"])
plt.subplot(1,2,2)
plt.scatter(x_scaled.index, x_scaled["AGE"])

# %% [markdown]
# ## Training Model After Scaling The Data

# %%
xs_train, xs_test, y_train, y_test = train_test_split(x_scaled,y)

# %%
lr_model = LinearRegression()
lr_model.fit(xs_train,y_train)
y_pred = lr_model.predict(xs_test)

# %%
mse = mean_squared_error(y_test,y_pred)
rmse = np.sqrt(mse)
mae = mean_absolute_error(y_test,y_pred)
r2score = r2_score(y_test,y_pred)

print(f"Mean Squared Error: {mse:0.4f}")
print(f"Root mean Squared Error: {rmse:0.4f}")
print(f"Mean Absolute Error: {mae:0.4f}")
print(f"R2 Score: {r2score:0.4f}")
# Out:
# Mean Squared Error: 24.1536
# Root mean Squared Error: 4.9146
# Mean Absolute Error: 3.4218
# R2 Score: 0.7000

# %%
# Previous Score / Before Scaling
# Mean Squared Error: 27.8526
# Root mean Squared Error: 5.2776
# Mean Absolute Error: 3.4776
# R2 Score: 0.6376

# %%
residual = y_test - y_pred

# %% [markdown]
# ### No Autocorrelation of Error

# %%
plt.plot(np.array(residual))

# %%
plt.scatter(residual.index, residual)

# %%
residual
# Out:
# 168    -2.948665
# 193    -1.602760
# 458    -2.003714
# 407     8.743440
# 369    18.822280
#          ...
# 151     1.490473
# 459     1.947713
# 230     0.112907
# 438     3.110971
# 368    28.044888
# Name: House_Price, Length: 127, dtype: float64

# %%
sns.kdeplot(residual)
# Out:
# <AxesSubplot:xlabel='House_Price', ylabel='Density'>

# %% [markdown]
# ### Checking Homoscedesticity

# %%
plt.scatter(y_pred, residual)

# %% [markdown]
# ### Continuing with EDA

# %% [markdown]
# ### Testing if the data is normally distritubed
